# %%
# Importing the libraries
import numpy as np
import matplotlib.pyplot as plt
plt.style.use('seaborn-darkgrid')
import pandas as pd
from sklearn.preprocessing import MinMaxScaler
from keras.models import Sequential
from keras.layers import Dense, LSTM, Dropout, GRU, Bidirectional
from keras.optimizers import SGD
import math
from sklearn.metrics import mean_squared_error
import tensorflow as tf

# %%
import yfinance as yf

# %%
# Some functions to help out with
def plot_predictions(test,predicted):
    plt.plot(test, color='red',label='Real RELIANCE Stock Price')
    plt.plot(predicted, color='blue',label='Predicted RELIANCE Stock Price')
    plt.title('RELIANCE Stock Price Prediction')
    plt.xlabel('Time')
    plt.ylabel('RELIANCE Stock Price')
    plt.legend()
    plt.show()

# %%
#see the yahoo finance ticker for your stock symbol
stock_symbol = "RELIANCE.NS"

# %%
#last 5 years data with interval of 1 day
data = yf.download(tickers=stock_symbol, period='5y', interval='1d')
# Out:
# [*********************100%***********************]  1 of 1 completed

# %%
data.head()
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2018-04-30  972.779053  983.279480  950.985596  954.254639  933.830017
# 2018-05-02  957.919861  970.005310  955.988159  963.566345  942.942383
# 2018-05-03  968.717529  968.717529  950.242676  952.570557  932.181946
# 2018-05-04  953.808838  955.641479  941.079529  944.992432  924.766052
# 2018-05-07  949.846375  964.111206  947.369873  961.882324  941.294373
#
#              Volume
# Date
# 2018-04-30  8955897
# 2018-05-02  6175751
# 2018-05-03  3984964
# 2018-05-04  3831671
# 2018-05-07  3545827

# %%
# Checking for missing values
training_set = data[:'2022-04'].iloc[:,1:2].values
test_set = data['2022-04':].iloc[:,1:2].values

# %%
# We have chosen 'Open' attribute for prices. Let's see what it looks like
data["Open"][:'2022-04'].plot(figsize=(16,4),legend=True)
data["Open"]['2022-04':].plot(figsize=(16,4),legend=True)
plt.legend(['Training set (Before 2021)','Test set (2022 and beyond)'])
plt.title('RELIANCE stock Open price')
plt.show()

# %%
opn = data[['Open']]

# %%
opn.plot(figsize=(16,4),legend=True)
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
ds = opn.values

# %%
ds
# Out:
# array([[ 972.77905273],
#        [ 957.91986084],
#        [ 968.7175293 ],
#        ...,
#        [2379.        ],
#        [2375.        ],
#        [2382.        ]])

# %%
#Using MinMaxScaler for normalizing data between 0 & 1
normalizer = MinMaxScaler(feature_range=(0,1))
ds_scaled = normalizer.fit_transform(np.array(ds).reshape(-1,1))

# %%
len(ds_scaled), len(ds)
# Out:
# (1235, 1235)

# %%
#Defining test and train data sizes
train_size = int(len(data[:'2022-04']))
test_size = int(len(data['2022-04':]))

# %%
train_size, test_size
# Out:
# (988, 266)

# %%
#Splitting data between train and test
ds_train, ds_test = ds_scaled[0:train_size,:], ds_scaled[train_size:len(ds_scaled),:1]

# %%
len(ds_train), len(ds_test)
# Out:
# (988, 247)

# %%
#Creating dataset in time series for GRU model
#X[100,120,140,160,180] : Y[200]
def create_ds(dataset, step):
    Xtrain, Ytrain = [], []
    for i in range(len(dataset)-step-1):
        a = dataset[i:(i+step), 0]
        Xtrain.append(a)
        Ytrain.append(dataset[i + step, 0])
    return np.array(Xtrain), np.array(Ytrain)

# %%
#Taking 100 days price as one record for training
time_stamp = 100
X_train, Y_train = create_ds(ds_train, time_stamp)
X_test, Y_test = create_ds(ds_test, time_stamp)

# %%
X_train.shape, Y_train.shape
# Out:
# ((887, 100), (887,))

# %%
X_test.shape, Y_test.shape
# Out:
# ((146, 100), (146,))

# %%
#Reshaping data to fit into GRU model
X_train = X_train.reshape(X_train.shape[0], X_train.shape[1], 1)
X_test = X_test.reshape(X_test.shape[0], X_test.shape[1], 1)

# %%
# The GRU architecture
model = Sequential()
# First GRU layer with Dropout regularisation
model.add(GRU(units=50, return_sequences=True, input_shape=(X_train.shape[1],1), activation='tanh'))
model.add(Dropout(0.2))
# Second GRU layer
model.add(GRU(units=50, return_sequences=True, input_shape=(X_train.shape[1],1), activation='tanh'))
model.add(Dropout(0.2))
# Third GRU layer
model.add(GRU(units=50, return_sequences=True, input_shape=(X_train.shape[1],1), activation='tanh'))
model.add(Dropout(0.2))
# Fourth GRU layer
model.add(GRU(units=50, activation='tanh'))
model.add(Dropout(0.2))
# The output layer
model.add(Dense(units=1))

# %%
#Training model with optimizer and mean squared error loss function
model.compile(loss='mean_squared_error', optimizer='SGD')
model.fit(X_train, Y_train, validation_data=(X_test, Y_test), epochs=100, batch_size=64)
model.evaluate(X_train, Y_train)
# Out:
# Epoch 1/100
# 14/14 [==============================] - 10s 283ms/step - loss: 0.1236 - val_loss: 0.1615
# Epoch 2/100
# 14/14 [==============================] - 3s 190ms/step - loss: 0.0631 - val_loss: 0.1155
# Epoch 3/100
# 14/14 [==============================] - 2s 177ms/step - loss: 0.0590 - val_loss: 0.1092
# Epoch 4/100
# 14/14 [==============================] - 2s 178ms/step - loss: 0.0563 - val_loss: 0.0962
# Epoch 5/100
# 14/14 [==============================] - 3s 183ms/step - loss: 0.0531 - val_loss: 0.0940
# Epoch 6/100
# 14/14 [==============================] - 3s 180ms/step - loss: 0.0512 - val_loss: 0.0833
# Epoch 7/100
# 14/14 [==============================] - 3s 182ms/step - loss: 0.0489 - val_loss: 0.0910
# Epoch 8/100
# 14/14 [==============================] - 3s 185ms/step - loss: 0.0452 - val_loss: 0.0819
# Epoch 9/100
# 14/14 [==============================] - 3s 186ms/step - loss: 0.0436 - val_loss: 0.0733
# Epoch 10/100
# 14/14 [==============================] - 3s 181ms/step - loss: 0.0408 - val_loss: 0.0691
# Epoch 11/100
# 14/14 [==============================] - 3s 183ms/step - loss: 0.0381 - val_loss: 0.0640
# Epoch 12/100
# 14/14 [==============================] - 3s 185ms/step - loss: 0.0348 - val_loss: 0.0601
# Epoch 13/100
# 14/14 [==============================] - 3s 185ms/step - loss: 0.0338 - val_loss: 0.0531
# Epoch 14/100
# 14/14 [==============================] - 3s 188ms/step - loss: 0.0297 - val_loss: 0.0493
# Epoch 15/100
# 14/14 [==============================] - 3s 185ms/step - loss: 0.0290 - val_loss: 0.0416
# Epoch 16/100
# 14/14 [==============================] - 3s 188ms/step - loss: 0.0260 - val_loss: 0.0389
# Epoch 17/100
# 14/14 [==============================] - 3s 187ms/step - loss: 0.0226 - val_loss: 0.0360
# Epoch 18/100
# 14/14 [==============================] - 3s 185ms/step - loss: 0.0203 - val_loss: 0.0317
# Epoch 19/100
# 14/14 [==============================] - 3s 186ms/step - loss: 0.0184 - val_loss: 0.0246
# Epoch 20/100
# 14/14 [==============================] - 3s 186ms/step - loss: 0.0157 - val_loss: 0.0227
# Epoch 21/100
# 14/14 [==============================] - 3s 186ms/step - loss: 0.0137 - val_loss: 0.0184
# Epoch 22/100
# 14/14 [==============================] - 3s 187ms/step - loss: 0.0126 - val_loss: 0.0133
# Epoch 23/100
# 14/14 [==============================] - 3s 194ms/step - loss: 0.0115 - val_loss: 0.0114
# Epoch 24/100
# 14/14 [==============================] - 3s 189ms/step - loss: 0.0096 - val_loss: 0.0097
# Epoch 25/100
# 14/14 [==============================] - 3s 193ms/step - loss: 0.0079 - val_loss: 0.0080
# Epoch 26/100
# 14/14 [==============================] - 3s 192ms/step - loss: 0.0080 - val_loss: 0.0069
# Epoch 27/100
# 14/14 [==============================] - 3s 187ms/step - loss: 0.0071 - val_loss: 0.0052
# Epoch 28/100
# 14/14 [==============================] - 3s 186ms/step - loss: 0.0070 - val_loss: 0.0041
# Epoch 29/100
# 14/14 [==============================] - 3s 186ms/step - loss: 0.0064 - val_loss: 0.0036
# Epoch 30/100
# 14/14 [==============================] - 3s 189ms/step - loss: 0.0060 - val_loss: 0.0036
# Epoch 31/100
# 14/14 [==============================] - 3s 193ms/step - loss: 0.0056 - val_loss: 0.0026
# Epoch 32/100
# 14/14 [==============================] - 3s 192ms/step - loss: 0.0053 - val_loss: 0.0027
# Epoch 33/100
# 14/14 [==============================] - 3s 187ms/step - loss: 0.0053 - val_loss: 0.0021
# Epoch 34/100
# 14/14 [==============================] - 3s 188ms/step - loss: 0.0055 - val_loss: 0.0015
# Epoch 35/100
# 14/14 [==============================] - 3s 190ms/step - loss: 0.0048 - val_loss: 0.0018
# Epoch 36/100
# 14/14 [==============================] - 3s 192ms/step - loss: 0.0047 - val_loss: 0.0014
# Epoch 37/100
# 14/14 [==============================] - 3s 189ms/step - loss: 0.0053 - val_loss: 0.0014
# Epoch 38/100
# 14/14 [==============================] - 3s 189ms/step - loss: 0.0049 - val_loss: 0.0014
# Epoch 39/100
# 14/14 [==============================] - 3s 199ms/step - loss: 0.0049 - val_loss: 0.0013
# Epoch 40/100
# 14/14 [==============================] - 3s 194ms/step - loss: 0.0049 - val_loss: 0.0012
# Epoch 41/100
# 14/14 [==============================] - 3s 189ms/step - loss: 0.0050 - val_loss: 0.0012
# Epoch 42/100
# 14/14 [==============================] - 3s 189ms/step - loss: 0.0048 - val_loss: 0.0011
# Epoch 43/100
# 14/14 [==============================] - 3s 192ms/step - loss: 0.0045 - val_loss: 0.0011
# Epoch 44/100
# 14/14 [==============================] - 3s 188ms/step - loss: 0.0049 - val_loss: 0.0011
# Epoch 45/100
# 14/14 [==============================] - 3s 190ms/step - loss: 0.0045 - val_loss: 0.0012
# Epoch 46/100
# 14/14 [==============================] - 3s 190ms/step - loss: 0.0050 - val_loss: 0.0011
# Epoch 47/100
# 14/14 [==============================] - 3s 198ms/step - loss: 0.0041 - val_loss: 0.0011
# Epoch 48/100
# 14/14 [==============================] - 3s 189ms/step - loss: 0.0046 - val_loss: 0.0011
# Epoch 49/100
# 14/14 [==============================] - 3s 191ms/step - loss: 0.0047 - val_loss: 0.0011
# Epoch 50/100
# 14/14 [==============================] - 3s 189ms/step - loss: 0.0041 - val_loss: 0.0011
# Epoch 51/100
# 14/14 [==============================] - 3s 189ms/step - loss: 0.0046 - val_loss: 0.0011
# Epoch 52/100
# 14/14 [==============================] - 3s 191ms/step - loss: 0.0040 - val_loss: 0.0011
# Epoch 53/100
# 14/14 [==============================] - 3s 195ms/step - loss: 0.0041 - val_loss: 0.0011
# Epoch 54/100
# 14/14 [==============================] - 3s 199ms/step - loss: 0.0047 - val_loss: 0.0011
# Epoch 55/100
# 14/14 [==============================] - 3s 202ms/step - loss: 0.0040 - val_loss: 0.0011
# Epoch 56/100
# 14/14 [==============================] - 3s 192ms/step - loss: 0.0042 - val_loss: 0.0012
# Epoch 57/100
# 14/14 [==============================] - 3s 194ms/step - loss: 0.0040 - val_loss: 0.0011
# Epoch 58/100
# 14/14 [==============================] - 3s 195ms/step - loss: 0.0040 - val_loss: 0.0011
# Epoch 59/100
# 14/14 [==============================] - 3s 193ms/step - loss: 0.0047 - val_loss: 0.0011
# Epoch 60/100
# 14/14 [==============================] - 3s 191ms/step - loss: 0.0044 - val_loss: 0.0011
# Epoch 61/100
# 14/14 [==============================] - 3s 192ms/step - loss: 0.0043 - val_loss: 0.0012
# Epoch 62/100
# 14/14 [==============================] - 3s 191ms/step - loss: 0.0046 - val_loss: 0.0011
# Epoch 63/100
# 14/14 [==============================] - 3s 191ms/step - loss: 0.0043 - val_loss: 0.0011
# Epoch 64/100
# 14/14 [==============================] - 3s 193ms/step - loss: 0.0041 - val_loss: 0.0011
# Epoch 65/100
# 14/14 [==============================] - 3s 192ms/step - loss: 0.0042 - val_loss: 0.0011
# Epoch 66/100
# 14/14 [==============================] - 3s 193ms/step - loss: 0.0039 - val_loss: 0.0013
# Epoch 67/100
# 14/14 [==============================] - 3s 196ms/step - loss: 0.0042 - val_loss: 0.0011
# Epoch 68/100
# 14/14 [==============================] - 3s 192ms/step - loss: 0.0038 - val_loss: 0.0011
# Epoch 69/100
# 14/14 [==============================] - 3s 193ms/step - loss: 0.0045 - val_loss: 0.0011
# Epoch 70/100
# 14/14 [==============================] - 3s 193ms/step - loss: 0.0040 - val_loss: 0.0011
# Epoch 71/100
# 14/14 [==============================] - 3s 201ms/step - loss: 0.0037 - val_loss: 0.0013
# Epoch 72/100
# 14/14 [==============================] - 3s 197ms/step - loss: 0.0042 - val_loss: 0.0011
# Epoch 73/100
# 14/14 [==============================] - 3s 192ms/step - loss: 0.0040 - val_loss: 0.0011
# Epoch 74/100
# 14/14 [==============================] - 3s 194ms/step - loss: 0.0038 - val_loss: 0.0011
# Epoch 75/100
# 14/14 [==============================] - 3s 195ms/step - loss: 0.0043 - val_loss: 0.0011
# Epoch 76/100
# 14/14 [==============================] - 3s 193ms/step - loss: 0.0041 - val_loss: 0.0011
# Epoch 77/100
# 14/14 [==============================] - 3s 193ms/step - loss: 0.0039 - val_loss: 0.0011
# Epoch 78/100
# 14/14 [==============================] - 3s 194ms/step - loss: 0.0038 - val_loss: 0.0011
# Epoch 79/100
# 14/14 [==============================] - 3s 194ms/step - loss: 0.0040 - val_loss: 0.0011
# Epoch 80/100
# 14/14 [==============================] - 3s 195ms/step - loss: 0.0041 - val_loss: 0.0011
# Epoch 81/100
# 14/14 [==============================] - 3s 194ms/step - loss: 0.0041 - val_loss: 0.0011
# Epoch 82/100
# 14/14 [==============================] - 3s 194ms/step - loss: 0.0042 - val_loss: 0.0011
# Epoch 83/100
# 14/14 [==============================] - 3s 193ms/step - loss: 0.0039 - val_loss: 0.0012
# Epoch 84/100
# 14/14 [==============================] - 3s 197ms/step - loss: 0.0039 - val_loss: 0.0011
# Epoch 85/100
# 14/14 [==============================] - 3s 192ms/step - loss: 0.0041 - val_loss: 0.0011
# Epoch 86/100
# 14/14 [==============================] - 3s 191ms/step - loss: 0.0041 - val_loss: 0.0011
# Epoch 87/100
# 14/14 [==============================] - 3s 191ms/step - loss: 0.0042 - val_loss: 0.0011
# Epoch 88/100
# 14/14 [==============================] - 3s 193ms/step - loss: 0.0039 - val_loss: 0.0011
# Epoch 89/100
# 14/14 [==============================] - 3s 193ms/step - loss: 0.0038 - val_loss: 0.0011
# Epoch 90/100
# 14/14 [==============================] - 3s 192ms/step - loss: 0.0037 - val_loss: 0.0011
# Epoch 91/100
# 14/14 [==============================] - 3s 197ms/step - loss: 0.0040 - val_loss: 0.0011
# Epoch 92/100
# 14/14 [==============================] - 3s 193ms/step - loss: 0.0043 - val_loss: 0.0011
# Epoch 93/100
# 14/14 [==============================] - 3s 193ms/step - loss: 0.0037 - val_loss: 0.0011
# Epoch 94/100
# 14/14 [==============================] - 3s 196ms/step - loss: 0.0037 - val_loss: 0.0011
# Epoch 95/100
# 14/14 [==============================] - 3s 192ms/step - loss: 0.0038 - val_loss: 0.0011
# Epoch 96/100
# 14/14 [==============================] - 3s 193ms/step - loss: 0.0037 - val_loss: 0.0011
# Epoch 97/100
# 14/14 [==============================] - 3s 194ms/step - loss: 0.0040 - val_loss: 0.0011
# Epoch 98/100
# 14/14 [==============================] - 3s 198ms/step - loss: 0.0038 - val_loss: 0.0012
# Epoch 99/100
# 14/14 [==============================] - 3s 193ms/step - loss: 0.0039 - val_loss: 0.0011
# Epoch 100/100
# 14/14 [==============================] - 3s 195ms/step - loss: 0.0038 - val_loss: 0.0011
# 28/28 [==============================] - 1s 38ms/step - loss: 0.0014
# 0.0014375540195032954

# %%
#Predicting on train and test data
train_predict = model.predict(X_train)
test_predict = model.predict(X_test)
# Out:
# 28/28 [==============================] - 2s 42ms/step
# 5/5 [==============================] - 0s 44ms/step

# %%
#Inverse transform to get actual value
train_predict = normalizer.inverse_transform(train_predict)
test_predict = normalizer.inverse_transform(test_predict)

# %%
#Comparing using visuals
plt.plot(normalizer.inverse_transform(ds_scaled))
plt.plot(train_predict)
plt.plot(test_predict)

# %%
test = np.vstack((train_predict, test_predict))

# %%
#combining the predicted data to create uniform data visualization
plt.plot(normalizer.inverse_transform(ds_scaled))
plt.plot(test)

# %%
len(ds_test)
# Out:
# 247

# %%
#Getting last 100 days records
fut_inp = ds_test[147:]

# %%
fut_inp = fut_inp.reshape(1,-1)

# %%
tmp_inp = list(fut_inp)

# %%
fut_inp.shape
# Out:
# (1, 100)

# %%
#Creating list of the last 100 data
tmp_inp = tmp_inp[0].tolist()

# %%
#Predicting next 30 days price using the current data
#It will predict in sliding window manner (algorithm) with stride 1
lst_output=[]
n_steps=100
i=0
while(i<10):
    
    if(len(tmp_inp)>100):
        fut_inp = np.array(tmp_inp[1:])
        fut_inp = fut_inp.reshape(1,-1)
        fut_inp = fut_inp.reshape((1, n_steps, 1))
        yhat = model.predict(fut_inp, verbose=0)
        tmp_inp.extend(yhat[0].tolist())
        tmp_inp = tmp_inp[1:]
        lst_output.extend(yhat.tolist())
        i = i+1
    else:
        fut_inp = fut_inp.reshape((1, n_steps, 1))
        yhat = model.predict(fut_inp, verbose=0)
        tmp_inp.extend(yhat[0].tolist())
        lst_output.extend(yhat.tolist())
        i = i+1
        
        
print(lst_output)
# Out:
# [[0.7422860264778137], [0.7431657314300537], [0.743405282497406], [0.7431193590164185], [0.7425003051757812], [0.7417086362838745], [0.7408465147018433], [0.7399665713310242], [0.7390913367271423], [0.7382276654243469]]

# %%
len(ds_scaled)
# Out:
# 1235

# %%
#Creating a dummy plane to plot graph one after another
plot_new=np.arange(1,101)
plot_pred=np.arange(101,111)

# %%
plt.plot(plot_new, normalizer.inverse_transform(ds_scaled[1135:]))
plt.plot(plot_pred, normalizer.inverse_transform(lst_output))

# %%
ds_new = ds_scaled.tolist()

# %%
len(ds_new)
# Out:
# 1235

# %%
#Extends helps us to fill the missing value with approx value
ds_new.extend(lst_output)
plt.plot(ds_new[1200:])

# %%
#Creating final data for plotting
final_graph = normalizer.inverse_transform(ds_new).tolist()

# %%
#Plotting final results with predicted value after 30 Days
plt.plot(final_graph,)
plt.ylabel("Price")
plt.xlabel("Time")
plt.title("{0} prediction of next month high".format(stock_symbol))
plt.axhline(y=final_graph[len(final_graph)-1], color = 'red', linestyle = ':', label = 'NEXT 10D: {0}'.format(round(float(*final_graph[len(final_graph)-1]),2)))
plt.legend()
