# %%
# Importing the libraries
import numpy as np
import matplotlib.pyplot as plt
plt.style.use('seaborn-darkgrid')
import pandas as pd
from sklearn.preprocessing import MinMaxScaler
from keras.models import Sequential
from keras.layers import Dense, LSTM, Dropout, GRU, Bidirectional
from keras.optimizers import SGD
import math
from sklearn.metrics import mean_squared_error
import tensorflow as tf

# %%
import yfinance as yf

# %%
# Some functions to help out with
def plot_predictions(test,predicted):
    plt.plot(test, color='red',label='Real RELIANCE Stock Price')
    plt.plot(predicted, color='blue',label='Predicted RELIANCE Stock Price')
    plt.title('RELIANCE Stock Price Prediction')
    plt.xlabel('Time')
    plt.ylabel('RELIANCE Stock Price')
    plt.legend()
    plt.show()

# %%
#see the yahoo finance ticker for your stock symbol
stock_symbol = "RELIANCE.NS"

# %%
#last 5 years data with interval of 1 day
data = yf.download(tickers=stock_symbol, period='5y', interval='1d')
# Out:
# [*********************100%***********************]  1 of 1 completed

# %%
data.head()
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2018-04-30  972.779053  983.279480  950.985596  954.254639  933.830017
# 2018-05-02  957.919861  970.005310  955.988159  963.566345  942.942444
# 2018-05-03  968.717529  968.717529  950.242676  952.570557  932.181946
# 2018-05-04  953.808838  955.641479  941.079529  944.992432  924.765991
# 2018-05-07  949.846375  964.111206  947.369873  961.882324  941.294434
#
#              Volume
# Date
# 2018-04-30  8955897
# 2018-05-02  6175751
# 2018-05-03  3984964
# 2018-05-04  3831671
# 2018-05-07  3545827

# %%
# Checking for missing values
training_set = data[:'2022-04'].iloc[:,1:2].values
test_set = data['2022-04':].iloc[:,1:2].values

# %%
# We have chosen 'Open' attribute for prices. Let's see what it looks like
data["Open"][:'2022-04'].plot(figsize=(16,4),legend=True)
data["Open"]['2022-04':].plot(figsize=(16,4),legend=True)
plt.legend(['Training set (Before 2021)','Test set (2022 and beyond)'])
plt.title('RELIANCE stock open price')
plt.show()

# %%
opn = data[['Open']]

# %%
opn.plot(figsize=(16,4),legend=True)
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
ds = opn.values

# %%
ds
# Out:
# array([[ 972.77905273],
#        [ 957.91986084],
#        [ 968.7175293 ],
#        ...,
#        [2379.        ],
#        [2375.        ],
#        [2382.        ]])

# %%
#Using MinMaxScaler for normalizing data between 0 & 1
normalizer = MinMaxScaler(feature_range=(0,1))
ds_scaled = normalizer.fit_transform(np.array(ds).reshape(-1,1))

# %%
len(ds_scaled), len(ds)
# Out:
# (1235, 1235)

# %%
#Defining test and train data sizes
train_size = int(len(data[:'2022-04']))
test_size = int(len(data['2022-04':]))

# %%
train_size, test_size
# Out:
# (988, 266)

# %%
#Splitting data between train and test
ds_train, ds_test = ds_scaled[0:train_size,:], ds_scaled[train_size:len(ds_scaled),:1]

# %%
len(ds_train), len(ds_test)
# Out:
# (988, 247)

# %%
#Creating dataset in time series for GRU model
#X[100,120,140,160,180] : Y[200]
def create_ds(dataset, step):
    Xtrain, Ytrain = [], []
    for i in range(len(dataset)-step-1):
        a = dataset[i:(i+step), 0]
        Xtrain.append(a)
        Ytrain.append(dataset[i + step, 0])
    return np.array(Xtrain), np.array(Ytrain)

# %%
#Taking 100 days price as one record for training
time_stamp = 100
X_train, Y_train = create_ds(ds_train, time_stamp)
X_test, Y_test = create_ds(ds_test, time_stamp)

# %%
X_train.shape, Y_train.shape
# Out:
# ((887, 100), (887,))

# %%
X_test.shape, Y_test.shape
# Out:
# ((146, 100), (146,))

# %%
#Reshaping data to fit into BiGRU model
X_train = X_train.reshape(X_train.shape[0], X_train.shape[1], 1)
X_test = X_test.reshape(X_test.shape[0], X_test.shape[1], 1)

# %%
#Creating LSTM model using keras
model = Sequential()
model.add(LSTM(units=50, return_sequences=True, input_shape=(X_train.shape[1],1), activation='tanh'))
model.add(Dropout(0.2))
model.add(LSTM(units=50, return_sequences=True, input_shape=(X_train.shape[1],1), activation='tanh'))
model.add(Dropout(0.2))
model.add(LSTM(units=50, return_sequences=True, input_shape=(X_train.shape[1],1), activation='tanh'))
model.add(Dropout(0.2))
model.add(LSTM(units=50, activation='tanh'))
model.add(Dropout(0.2))
model.add(Dense(units=1))

# %%
model.compile(loss='mean_squared_error', optimizer='adam')
history = model.fit(X_train, Y_train, validation_data=(X_test, Y_test), epochs=100, batch_size=128)
model.evaluate(X_train, Y_train)
print(history.history['loss'])
# Out:
# Epoch 1/100
# 7/7 [==============================] - 11s 677ms/step - loss: 0.1051 - val_loss: 0.0472
# Epoch 2/100
# 7/7 [==============================] - 3s 434ms/step - loss: 0.0241 - val_loss: 0.0531
# Epoch 3/100
# 7/7 [==============================] - 3s 432ms/step - loss: 0.0160 - val_loss: 0.0077
# Epoch 4/100
# 7/7 [==============================] - 3s 433ms/step - loss: 0.0108 - val_loss: 0.0133
# Epoch 5/100
# 7/7 [==============================] - 3s 442ms/step - loss: 0.0088 - val_loss: 0.0046
# Epoch 6/100
# 7/7 [==============================] - 3s 451ms/step - loss: 0.0077 - val_loss: 0.0028
# Epoch 7/100
# 7/7 [==============================] - 3s 442ms/step - loss: 0.0076 - val_loss: 0.0037
# Epoch 8/100
# 7/7 [==============================] - 3s 441ms/step - loss: 0.0070 - val_loss: 0.0029
# Epoch 9/100
# 7/7 [==============================] - 3s 453ms/step - loss: 0.0068 - val_loss: 0.0029
# Epoch 10/100
# 7/7 [==============================] - 3s 444ms/step - loss: 0.0065 - val_loss: 0.0029
# Epoch 11/100
# 7/7 [==============================] - 3s 442ms/step - loss: 0.0061 - val_loss: 0.0029
# Epoch 12/100
# 7/7 [==============================] - 3s 451ms/step - loss: 0.0061 - val_loss: 0.0032
# Epoch 13/100
# 7/7 [==============================] - 3s 445ms/step - loss: 0.0060 - val_loss: 0.0025
# Epoch 14/100
# 7/7 [==============================] - 3s 430ms/step - loss: 0.0058 - val_loss: 0.0033
# Epoch 15/100
# 7/7 [==============================] - 3s 442ms/step - loss: 0.0059 - val_loss: 0.0024
# Epoch 16/100
# 7/7 [==============================] - 3s 443ms/step - loss: 0.0060 - val_loss: 0.0026
# Epoch 17/100
# 7/7 [==============================] - 3s 447ms/step - loss: 0.0051 - val_loss: 0.0029
# Epoch 18/100
# 7/7 [==============================] - 3s 449ms/step - loss: 0.0059 - val_loss: 0.0025
# Epoch 19/100
# 7/7 [==============================] - 3s 442ms/step - loss: 0.0061 - val_loss: 0.0024
# Epoch 20/100
# 7/7 [==============================] - 3s 439ms/step - loss: 0.0057 - val_loss: 0.0028
# Epoch 21/100
# 7/7 [==============================] - 3s 445ms/step - loss: 0.0053 - val_loss: 0.0024
# Epoch 22/100
# 7/7 [==============================] - 3s 446ms/step - loss: 0.0053 - val_loss: 0.0023
# Epoch 23/100
# 7/7 [==============================] - 3s 451ms/step - loss: 0.0051 - val_loss: 0.0026
# Epoch 24/100
# 7/7 [==============================] - 3s 451ms/step - loss: 0.0050 - val_loss: 0.0024
# Epoch 25/100
# 7/7 [==============================] - 3s 449ms/step - loss: 0.0049 - val_loss: 0.0022
# Epoch 26/100
# 7/7 [==============================] - 3s 460ms/step - loss: 0.0054 - val_loss: 0.0028
# Epoch 27/100
# 7/7 [==============================] - 3s 448ms/step - loss: 0.0051 - val_loss: 0.0036
# Epoch 28/100
# 7/7 [==============================] - 3s 456ms/step - loss: 0.0051 - val_loss: 0.0023
# Epoch 29/100
# 7/7 [==============================] - 3s 457ms/step - loss: 0.0049 - val_loss: 0.0048
# Epoch 30/100
# 7/7 [==============================] - 3s 455ms/step - loss: 0.0053 - val_loss: 0.0036
# Epoch 31/100
# 7/7 [==============================] - 3s 453ms/step - loss: 0.0051 - val_loss: 0.0034
# Epoch 32/100
# 7/7 [==============================] - 3s 451ms/step - loss: 0.0050 - val_loss: 0.0020
# Epoch 33/100
# 7/7 [==============================] - 3s 456ms/step - loss: 0.0050 - val_loss: 0.0024
# Epoch 34/100
# 7/7 [==============================] - 3s 449ms/step - loss: 0.0044 - val_loss: 0.0024
# Epoch 35/100
# 7/7 [==============================] - 3s 449ms/step - loss: 0.0045 - val_loss: 0.0019
# Epoch 36/100
# 7/7 [==============================] - 3s 452ms/step - loss: 0.0047 - val_loss: 0.0019
# Epoch 37/100
# 7/7 [==============================] - 3s 467ms/step - loss: 0.0048 - val_loss: 0.0024
# Epoch 38/100
# 7/7 [==============================] - 3s 490ms/step - loss: 0.0045 - val_loss: 0.0019
# Epoch 39/100
# 7/7 [==============================] - 3s 496ms/step - loss: 0.0047 - val_loss: 0.0021
# Epoch 40/100
# 7/7 [==============================] - 3s 480ms/step - loss: 0.0044 - val_loss: 0.0019
# Epoch 41/100
# 7/7 [==============================] - 3s 458ms/step - loss: 0.0049 - val_loss: 0.0024
# Epoch 42/100
# 7/7 [==============================] - 3s 458ms/step - loss: 0.0045 - val_loss: 0.0023
# Epoch 43/100
# 7/7 [==============================] - 3s 454ms/step - loss: 0.0045 - val_loss: 0.0024
# Epoch 44/100
# 7/7 [==============================] - 3s 457ms/step - loss: 0.0044 - val_loss: 0.0029
# Epoch 45/100
# 7/7 [==============================] - 3s 455ms/step - loss: 0.0045 - val_loss: 0.0037
# Epoch 46/100
# 7/7 [==============================] - 3s 457ms/step - loss: 0.0043 - val_loss: 0.0038
# Epoch 47/100
# 7/7 [==============================] - 3s 456ms/step - loss: 0.0052 - val_loss: 0.0043
# Epoch 48/100
# 7/7 [==============================] - 3s 457ms/step - loss: 0.0047 - val_loss: 0.0032
# Epoch 49/100
# 7/7 [==============================] - 3s 459ms/step - loss: 0.0047 - val_loss: 0.0026
# Epoch 50/100
# 7/7 [==============================] - 3s 461ms/step - loss: 0.0045 - val_loss: 0.0016
# Epoch 51/100
# 7/7 [==============================] - 3s 459ms/step - loss: 0.0044 - val_loss: 0.0018
# Epoch 52/100
# 7/7 [==============================] - 3s 457ms/step - loss: 0.0039 - val_loss: 0.0016
# Epoch 53/100
# 7/7 [==============================] - 3s 472ms/step - loss: 0.0040 - val_loss: 0.0016
# Epoch 54/100
# 7/7 [==============================] - 3s 458ms/step - loss: 0.0044 - val_loss: 0.0019
# Epoch 55/100
# 7/7 [==============================] - 3s 455ms/step - loss: 0.0041 - val_loss: 0.0036
# Epoch 56/100
# 7/7 [==============================] - 3s 470ms/step - loss: 0.0042 - val_loss: 0.0041
# Epoch 57/100
# 7/7 [==============================] - 3s 465ms/step - loss: 0.0039 - val_loss: 0.0023
# Epoch 58/100
# 7/7 [==============================] - 3s 464ms/step - loss: 0.0040 - val_loss: 0.0015
# Epoch 59/100
# 7/7 [==============================] - 3s 463ms/step - loss: 0.0040 - val_loss: 0.0019
# Epoch 60/100
# 7/7 [==============================] - 3s 460ms/step - loss: 0.0038 - val_loss: 0.0028
# Epoch 61/100
# 7/7 [==============================] - 3s 463ms/step - loss: 0.0042 - val_loss: 0.0016
# Epoch 62/100
# 7/7 [==============================] - 3s 461ms/step - loss: 0.0036 - val_loss: 0.0015
# Epoch 63/100
# 7/7 [==============================] - 3s 460ms/step - loss: 0.0036 - val_loss: 0.0031
# Epoch 64/100
# 7/7 [==============================] - 3s 461ms/step - loss: 0.0039 - val_loss: 0.0020
# Epoch 65/100
# 7/7 [==============================] - 3s 460ms/step - loss: 0.0038 - val_loss: 0.0014
# Epoch 66/100
# 7/7 [==============================] - 3s 456ms/step - loss: 0.0037 - val_loss: 0.0022
# Epoch 67/100
# 7/7 [==============================] - 3s 461ms/step - loss: 0.0037 - val_loss: 0.0015
# Epoch 68/100
# 7/7 [==============================] - 3s 463ms/step - loss: 0.0036 - val_loss: 0.0016
# Epoch 69/100
# 7/7 [==============================] - 3s 460ms/step - loss: 0.0037 - val_loss: 0.0014
# Epoch 70/100
# 7/7 [==============================] - 3s 460ms/step - loss: 0.0036 - val_loss: 0.0014
# Epoch 71/100
# 7/7 [==============================] - 3s 465ms/step - loss: 0.0033 - val_loss: 0.0014
# Epoch 72/100
# 7/7 [==============================] - 3s 465ms/step - loss: 0.0034 - val_loss: 0.0014
# Epoch 73/100
# 7/7 [==============================] - 3s 466ms/step - loss: 0.0032 - val_loss: 0.0015
# Epoch 74/100
# 7/7 [==============================] - 3s 464ms/step - loss: 0.0035 - val_loss: 0.0028
# Epoch 75/100
# 7/7 [==============================] - 3s 467ms/step - loss: 0.0037 - val_loss: 0.0018
# Epoch 76/100
# 7/7 [==============================] - 3s 463ms/step - loss: 0.0034 - val_loss: 0.0014
# Epoch 77/100
# 7/7 [==============================] - 3s 460ms/step - loss: 0.0031 - val_loss: 0.0017
# Epoch 78/100
# 7/7 [==============================] - 3s 468ms/step - loss: 0.0038 - val_loss: 0.0017
# Epoch 79/100
# 7/7 [==============================] - 3s 461ms/step - loss: 0.0036 - val_loss: 0.0023
# Epoch 80/100
# 7/7 [==============================] - 3s 466ms/step - loss: 0.0039 - val_loss: 0.0014
# Epoch 81/100
# 7/7 [==============================] - 3s 463ms/step - loss: 0.0037 - val_loss: 0.0015
# Epoch 82/100
# 7/7 [==============================] - 3s 464ms/step - loss: 0.0035 - val_loss: 0.0017
# Epoch 83/100
# 7/7 [==============================] - 3s 465ms/step - loss: 0.0030 - val_loss: 0.0013
# Epoch 84/100
# 7/7 [==============================] - 3s 464ms/step - loss: 0.0034 - val_loss: 0.0015
# Epoch 85/100
# 7/7 [==============================] - 3s 460ms/step - loss: 0.0035 - val_loss: 0.0013
# Epoch 86/100
# 7/7 [==============================] - 3s 459ms/step - loss: 0.0031 - val_loss: 0.0013
# Epoch 87/100
# 7/7 [==============================] - 3s 460ms/step - loss: 0.0033 - val_loss: 0.0015
# Epoch 88/100
# 7/7 [==============================] - 3s 464ms/step - loss: 0.0034 - val_loss: 0.0013
# Epoch 89/100
# 7/7 [==============================] - 3s 462ms/step - loss: 0.0034 - val_loss: 0.0018
# Epoch 90/100
# 7/7 [==============================] - 3s 465ms/step - loss: 0.0033 - val_loss: 0.0021
# Epoch 91/100
# 7/7 [==============================] - 3s 463ms/step - loss: 0.0033 - val_loss: 0.0023
# Epoch 92/100
# 7/7 [==============================] - 3s 463ms/step - loss: 0.0033 - val_loss: 0.0020
# Epoch 93/100
# 7/7 [==============================] - 3s 465ms/step - loss: 0.0034 - val_loss: 0.0013
# Epoch 94/100
# 7/7 [==============================] - 3s 466ms/step - loss: 0.0031 - val_loss: 0.0018
# Epoch 95/100
# 7/7 [==============================] - 3s 466ms/step - loss: 0.0034 - val_loss: 0.0041
# Epoch 96/100
# 7/7 [==============================] - 3s 466ms/step - loss: 0.0033 - val_loss: 0.0021
# Epoch 97/100
# 7/7 [==============================] - 3s 487ms/step - loss: 0.0033 - val_loss: 0.0015
# Epoch 98/100
# 7/7 [==============================] - 4s 531ms/step - loss: 0.0032 - val_loss: 0.0014
# Epoch 99/100
# 7/7 [==============================] - 3s 470ms/step - loss: 0.0035 - val_loss: 0.0012
# Epoch 100/100
# 7/7 [==============================] - 3s 467ms/step - loss: 0.0030 - val_loss: 0.0018
# 28/28 [==============================] - 1s 46ms/step - loss: 0.0018
# [0.10510352998971939, 0.02413368411362171, 0.01603381149470806, 0.01080190110951662, 0.008765213191509247, 0.007742033805698156, 0.007601920980960131, 0.006955509074032307, 0.006805552635341883, 0.006547759287059307, 0.0061435457319021225, 0.006135405972599983, 0.006022075191140175, 0.005779262166470289, 0.005910823587328196, 0.0059525142423808575, 0.005135563667863607, 0.005889795254915953, 0.006068623624742031, 0.005722008179873228, 0.005317677278071642, 0.0052560181356966496, 0.00514117581769824, 0.00495609175413847, 0.004925218876451254, 0.0053591039031744, 0.0050505525432527065, 0.005076942965388298, 0.004896772559732199, 0.005250602960586548, 0.005093999207019806, 0.005034053232520819, 0.004998349118977785, 0.004443828947842121, 0.004522026516497135, 0.004683521576225758, 0.004797191359102726, 0.004511682782322168, 0.004663086961954832, 0.004419609438627958, 0.004860407672822475, 0.004526389762759209, 0.0045069013722240925, 0.0043806154280900955, 0.004508884623646736, 0.004298435989767313, 0.005172803532332182, 0.00473112752661109, 0.004737983923405409, 0.004487412981688976, 0.004360366612672806, 0.003881815355271101, 0.004032069351524115, 0.004433366935700178, 0.0041198874823749065, 0.004165604244917631, 0.003943985793739557, 0.004037946928292513, 0.003981367684900761, 0.00382493925280869, 0.004171948879957199, 0.0035747820511460304, 0.003612156957387924, 0.0038664250168949366, 0.0038468658458441496, 0.003687066026031971, 0.0037325627636164427, 0.003593680215999484, 0.003725085174664855, 0.003575702430680394, 0.0033386433497071266, 0.0034011995885521173, 0.0031676150392740965, 0.003493714611977339, 0.0036687504034489393, 0.0033756259363144636, 0.003123404923826456, 0.0038488630671054125, 0.003584838705137372, 0.0038675942923873663, 0.0037291045300662518, 0.003494155826047063, 0.003041644813492894, 0.0033680188935250044, 0.0034559345804154873, 0.0031357407569885254, 0.0033154545817524195, 0.00341916480101645, 0.0034208630677312613, 0.003314441302791238, 0.0032935566268861294, 0.0033466112799942493, 0.0033645189832895994, 0.003146479371935129, 0.003355954075232148, 0.0032723243348300457, 0.0032885561231523752, 0.0032274622935801744, 0.003516563680022955, 0.002980801509693265]

# %%
plt.plot(history.history['loss'])
plt.title('model loss')
plt.xlabel('epoch')
plt.legend(['loss'], loc='upper right')
plt.show()

# %%
#Predicting on train and test data
train_predict = model.predict(X_train)
test_predict = model.predict(X_test)
# Out:
# 28/28 [==============================] - 2s 39ms/step
# 5/5 [==============================] - 0s 39ms/step

# %%
#Inverse transform to get actual value
train_predict = normalizer.inverse_transform(train_predict)
test_predict = normalizer.inverse_transform(test_predict)

# %%
#Comparing using visuals
plt.plot(normalizer.inverse_transform(ds_scaled))
plt.plot(train_predict)
plt.plot(test_predict)

# %%
test = np.vstack((train_predict, test_predict))

# %%
#combining the predicted data to create uniform data visualization
plt.plot(normalizer.inverse_transform(ds_scaled))
plt.plot(test)

# %%
len(ds_test)
# Out:
# 247

# %%
#Getting last 100 days records
fut_inp = ds_test[147:]

# %%
fut_inp = fut_inp.reshape(1,-1)

# %%
tmp_inp = list(fut_inp)

# %%
fut_inp.shape
# Out:
# (1, 100)

# %%
#Creating list of the last 100 data
tmp_inp = tmp_inp[0].tolist()

# %%
#Predicting next 30 days price using the current data
#It will predict in sliding window manner (algorithm) with stride 1
lst_output=[]
n_steps=100
i=0
while(i<10):
    
    if(len(tmp_inp)>100):
        fut_inp = np.array(tmp_inp[1:])
        fut_inp = fut_inp.reshape(1,-1)
        fut_inp = fut_inp.reshape((1, n_steps, 1))
        yhat = model.predict(fut_inp, verbose=0)
        tmp_inp.extend(yhat[0].tolist())
        tmp_inp = tmp_inp[1:]
        lst_output.extend(yhat.tolist())
        i = i+1
    else:
        fut_inp = fut_inp.reshape((1, n_steps, 1))
        yhat = model.predict(fut_inp, verbose=0)
        tmp_inp.extend(yhat[0].tolist())
        lst_output.extend(yhat.tolist())
        i = i+1
        
        
print(lst_output)
# Out:
# [[0.7781781554222107], [0.7779570817947388], [0.7784742116928101], [0.779885470867157], [0.7821482419967651], [0.7850999236106873], [0.7885321974754333], [0.7922482490539551], [0.7960916757583618], [0.7999566197395325]]

# %%
len(ds_scaled)
# Out:
# 1235

# %%
#Creating a dummy plane to plot graph one after another
plot_new=np.arange(1,101)
plot_pred=np.arange(101,111)

# %%
plt.plot(plot_new, normalizer.inverse_transform(ds_scaled[1135:]))
plt.plot(plot_pred, normalizer.inverse_transform(lst_output))

# %%
ds_new = ds_scaled.tolist()

# %%
len(ds_new)
# Out:
# 1235

# %%
#Extends helps us to fill the missing value with approx value
ds_new.extend(lst_output)
plt.plot(ds_new[1200:])

# %%
#Creating final data for plotting
final_graph = normalizer.inverse_transform(ds_new).tolist()

# %%
#Plotting final results with predicted value after 30 Days
plt.plot(final_graph,)
plt.ylabel("Price")
plt.xlabel("Time")
plt.title("{0} prediction of next month open".format(stock_symbol))
plt.axhline(y=final_graph[len(final_graph)-1], color = 'red', linestyle = ':', label = 'NEXT 10D: {0}'.format(round(float(*final_graph[len(final_graph)-1]),2)))
plt.legend()
